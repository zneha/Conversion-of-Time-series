# %%
#  all imports
from termcolor import colored
from glob import glob
import os
import pprint
pp = pprint.PrettyPrinter(indent=4)
from pylab import *
from pandas import Series
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import scipy.io

# %%
filepath = "/media/deep/Storage/Neha-box/ECG-src/PRELIM/Manual Marking/NoisyECGData_fromManualMarking"
files = glob(filepath+'*/*.mat')
# print(files)

print(colored("len_of_files:",'green'), len(files))
# Out:
# len_of_files: 1000

# %%
time_series_window = 14400

for file in files:
    filepath = '/'.join(file.split('/')[:-1])
    filename = '/'.join(file.split('/')[-1:])
    filename = '/'.join(filename.split('.')[:-1])
    print(filename)
# Out:
# 3019659_20120109_EDF_noisy_data
# 4015886_20101201_EDF_noisy_data
# 5012317_20110830_EDF_noisy_data
# 6010202_20120420_EDF_noisy_data
# 3010023_20110817_EDF_noisy_data
# 3010090_20110915_EDF_noisy_data
# 3010104_20111027_EDF_noisy_data
# 3010139_20110210_EDF_noisy_data
# 3010155_20110511_EDF_noisy_data
# 3010201_20120320_EDF_noisy_data
# 3010317_20110413_EDF_noisy_data
# 3010422_20110321_EDF_noisy_data
# 3010457_20111109_EDF_noisy_data
# 3010511_20120201_EDF_noisy_data
# 3010538_20120425_EDF_noisy_data
# 3010570_20120403_EDF_noisy_data
# 3010600_20110420_EDF_noisy_data
# 3010724_20110811_EDF_noisy_data
# 3010740_20110303_EDF_noisy_data
# 3010970_20120104_EDF_noisy_data
# 3010988_20110626_EDF_noisy_data
# 3011020_20120326_EDF_noisy_data
# 3011097_20120328_EDF_noisy_data
# 3011143_20110901_EDF_noisy_data
# 3011330_20120417_EDF_noisy_data
# 3011429_20120318_EDF_noisy_data
# 3011437_20110606_EDF_noisy_data
# 3011445_20110602_EDF_noisy_data
# 3011461_20120110_EDF_noisy_data
# ...
