# %%
#  all imports
from termcolor import colored
from glob import glob
import os
from pylab import *
from pandas import Series
import matplotlib
import matplotlib.pyplot as plt
import math
import numpy as np
import scipy.io
from tools import create_time_serie, cos_sum, tabulate


#  import all data
filepath = r"Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\DataConvert\Ind File test"
files = glob(filepath+'*/*.mat')
print(colored("len_of_files:",'red'), len(files))

# declare your needs
time_series_window = 256
beat_number_start = 11904
beat_number_end = 11906

for file in files:
    filepath = '\\'.join(file.split('\\')[:])
    filename = '\\'.join(file.split('\\')[-1:])
    filename = '\\'.join(filename.split('.')[:-1])
    print(colored("file_proccesing:",'blue'), filename)

    mats = scipy.io.loadmat(filepath)
    data = mats['data'][0]
    serie = data['good_data'][0][0]
    if len(serie)==0:
        print('All data is good data')
    else:
        for i in range(beat_number_start, beat_number_end):
            start11 = (i)*time_series_window
            end11 = (i+1)*time_series_window
            n = time_series_window - len(serie[start11:end11])
            if n !=0:
                start1 = (i*time_series_window)
                end1 = (i+1)*time_series_window
                nn = time_series_window - len(serie[start1:end1])
                time_series_seg = np.pad(serie[start1:len(serie)], (0, nn), 'constant')
            else:
                start1 = (i)*time_series_window
                end1 = (i+1)*time_series_window
                time_series_seg = serie[start1:end1]
              
            min_ = np.amin(time_series_seg)
            max_ = np.amax(time_series_seg)
            scaled_time_series_seg = (2*time_series_seg - max_ - min_)/(max_ - min_)

            scaled_time_series_seg = np.where(scaled_time_series_seg >= 1., 1., scaled_time_series_seg)
            scaled_time_series_seg = np.where(scaled_time_series_seg <= -1., -1., scaled_time_series_seg)
            
            phi = np.arccos(scaled_time_series_seg)
            r = np.linspace(0, 1, len(scaled_time_series_seg))
            gaf = tabulate(phi, phi, cos_sum)
            print("beat_number_start",i)
            print("gaf",gaf)
# Out:
# len_of_files: 1
# file_proccesing: 3012972_20120508_EDF_good_data
# beat_number_start 11904
# gaf [[-0.60308881 -0.59261255 -0.58519654 ... -0.47457652 -0.45583952
#   -0.45413358]
#  [-0.59261255 -0.58203507 -0.57454907 ... -0.46303252 -0.44416842
#   -0.44245123]
#  [-0.58519654 -0.57454907 -0.56701469 ... -0.45488006 -0.43592865
#   -0.43420374]
#  ...
#  [-0.47457652 -0.46303252 -0.45488006 ... -0.33499317 -0.314975
#   -0.31315622]
#  [-0.45583952 -0.44416842 -0.43592865 ... -0.314975   -0.29481572
#   -0.29298461]
#  [-0.45413358 -0.44245123 -0.43420374 ... -0.31315622 -0.29298461
#   -0.29115243]]
# beat_number_start 11905
# gaf [[ 0.27368925  0.25377842  0.26274264 ... -0.2122295  -0.2050406
#   -0.19263253]
#  [ 0.25377842  0.23375946  0.24277123 ... -0.23235471 -0.225199
#   -0.21284554]
#  [ 0.26274264  0.24277123  0.2517621  ... -0.22331975 -0.21614874
#   -0.20377008]
#  ...
#  [-0.2122295  -0.23235471 -0.22331975 ... -0.6479869  -0.64237079
#   -0.63261628]
#  [-0.2050406  -0.225199   -0.21614874 ... -0.64237079 -0.63671998
#   -0.6269064 ]
#  [-0.19263253 -0.21284554 -0.20377008 ... -0.63261628 -0.6269064
#   -0.61699233]]
